# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %% [markdown]
# ![istockphoto-803141126-612x612.jpg](attachment:10bff459-b6e8-4cf3-abf5-a3e666722a01.jpg)

# %% [markdown]
# ![1.jpg](attachment:43e82241-032a-440a-87c4-b806cdbf903f.jpg)

# %%
img = ![1.jpg](attachment:43e82241-032a-440a-87c4-b806cdbf903f.jpg)

# %%
from IPython import display

# %%
image = Image.open("1.jpg")

# %%
quantized_image = image.quantize(colors=16)

# %%
quantized_image
# Out:
# <PIL.Image.Image image mode=P size=612x408 at 0x7EFFBBEE2750>
